# %% [markdown]
# # First look at the data

# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('zbiór_8.csv')

# %%
df
# Out:
#       szczegolnaFormaPrawna_Symbol  formaWlasnosci_Symbol  pkdKod  \
# 0                              117                    214    7010
# 1                              117                    214    4719
# 2                              117                    215     119
# 3                              117                    214     111
# 4                              117                    216    6910
# ...                            ...                    ...     ...
# 2995                           117                    214    6201
# 2996                           117                    214    7990
# 2997                           117                    214    5814
# 2998                           117                    215    4120
# 2999                           117                    214    4211
#
#       wsk_liczba_dni_istnienia       Aktywa  Aktywa_trwale  \
# 0                         4732     31576.85        1000.00
# ...
